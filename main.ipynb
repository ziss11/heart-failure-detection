# %%
import os
import pandas as pd
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner
from modules import components, pipeline

# %%
PIPELANE_NAME = "stroke-pipeline"

# Pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/transform.py"
TUNER_MODULE_FILE = "modules/tuner.py"
TRAINER_MODULE_FILE = "modules/trainer.py"

# Pipeline outputs
OUTPUT_BASE = "outputs"

serving_model_dir = os.path.join(OUTPUT_BASE, "serving_model")
pipeline_root = os.path.join(OUTPUT_BASE, PIPELANE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# %%
components = components.init_components(
    DATA_ROOT,
    trainer_module=TRAINER_MODULE_FILE,
    tuner_module=TUNER_MODULE_FILE,
    transform_module=TRANSFORM_MODULE_FILE,
    train_steps=1000,
    eval_steps=300,
    serving_model_dir=serving_model_dir,
)

pipeline = pipeline.init_pipeline(
    pipeline_root, 
    PIPELANE_NAME, 
    metadata_path, 
    components
)
BeamDagRunner().run(pipeline)
# Out:
# Trial 3 Complete [00h 00m 34s]
# binary_accuracy: 0.9516249895095825
#
# Best binary_accuracy So Far: 0.9567343592643738
# Total elapsed time: 00h 01m 35s
#
# Search: Running Trial #4
#
# Value             |Best Value So Far |Hyperparameter
# 1                 |3                 |num_hidden_layers
# 176               |208               |dense_unit
# 0.0001            |0.001             |learning_rate
# 2                 |2                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 1                 |1                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  gender_xf (InputLayer)         [(None, 3)]          0           []
#
#  ever_married_xf (InputLayer)   [(None, 3)]          0           []
#
#  work_type_xf (InputLayer)      [(None, 6)]          0           []
#
#  Residence_type_xf (InputLayer)  [(None, 3)]         0           []
#
#  smoking_status_xf (InputLayer)  [(None, 5)]         0           []
#
#  age_xf (InputLayer)            [(None, 1)]          0           []
#
#  hypertension_xf (InputLayer)   [(None, 1)]          0           []
#
#  heart_disease_xf (InputLayer)  [(None, 1)]          0           []
#
#  avg_glucose_level_xf (InputLay  [(None, 1)]         0           []
#  er)
#
#  concatenate (Concatenate)      (None, 24)           0           ['gender_xf[0][0]',
#                                                                   'ever_married_xf[0][0]',
#                                                                   'work_type_xf[0][0]',
#                                                                   'Residence_type_xf[0][0]',
#                                                                   'smoking_status_xf[0][0]',
#                                                                   'age_xf[0][0]',
#                                                                   'hypertension_xf[0][0]',
#                                                                   'heart_disease_xf[0][0]',
#                                                                   'avg_glucose_level_xf[0][0]']
#
#  dense (Dense)                  (None, 176)          4400        ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 176)          31152       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            177         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 35,729
# Trainable params: 35,729
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/2
#  595/1000 [================>.............] - ETA: 5s - loss: 0.2247 - binary_accuracy: 0.9496
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     570           executor_watcher.start()
# --> 571         executor_output = self._run_executor(execution_info)
#     572       except Exception as e:  # pylint: disable=broad-except
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     445     try:
# --> 446       executor_output = self._executor_operator.run_executor(execution_info)
#     447       code = executor_output.execution_result.code
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\components\tuner\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     121
# --> 122     tuner = search(input_dict, exec_properties, self._get_tmp_dir())
#     123
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\components\tuner\executor.py in search(input_dict, exec_properties, working_dir)
#     105   logging.info('Start tuning... Tuner ID: %s', result.tuner_id)
# --> 106   result.search(**tuner_fn_result.fit_kwargs)
#     107   logging.info('Finished tuning... Tuner ID: %s', result.tuner_id)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     182             self.on_trial_begin(trial)
# --> 183             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184             # `results` is None indicates user updated oracle in `run_trial()`.
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\tuners\hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     383             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 384         return super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#     385
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\tuner.py in run_trial(self, trial, *args, **kwargs)
#     294             copied_kwargs["callbacks"] = callbacks
# --> 295             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     296
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     221         model = self._try_build(hp)
# --> 222         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223         tuner_utils.validate_trial_results(
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     139         """
# --> 140         return model.fit(*args, **kwargs)
#     141
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2328\2722571367.py in <cell line: 17>()
#      15     components
#      16 )
# ---> 17 BeamDagRunner().run(pipeline)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\tfx_runner.py in run(self, pipeline, run_options, **kwargs)
#     122     else:
#     123       run_options_pb = None
# --> 124     return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in run_with_ir(self, pipeline, run_options)
#     295                       pipeline=pipeline),
#     296                   *[beam.pvalue.AsIter(s) for s in signals_to_wait]))
# --> 297           logging.info('Node %s is scheduled.', node_id)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     595     try:
#     596       if not exc_type:
# --> 597         self.result = self.run()
#     598         self.result.wait_until_finish()
#     599     finally:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\pipeline.py in run(self, test_runner_api)
#     572         finally:
#     573           shutil.rmtree(tmpdir)
# --> 574       return self.runner.run_pipeline(self, self._options)
#     575     finally:
#     576       if not is_in_ipython():
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\direct\direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_pipeline(self, pipeline, options)
#     197         options.view_as(pipeline_options.ProfilingOptions))
#     198
# --> 199     self._latest_run_result = self.run_via_runner_api(
#     200         pipeline.to_runner_api(default_environment=self._default_environment),
#     201         options)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_via_runner_api(self, pipeline_proto, options)
#     210       pipeline_proto = self.embed_default_docker_image(pipeline_proto)
#     211     stage_context, stages = self.create_stages(pipeline_proto)
# --> 212     return self.run_stages(stage_context, stages)
#     213
#     214   def embed_default_docker_image(self, pipeline_proto):
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_stages(self, stage_context, stages)
#     440
#     441           bundle_counter += 1
# --> 442           bundle_results = self._execute_bundle(
#     443               runner_execution_context, bundle_context_manager, bundle_input)
#     444
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _execute_bundle(self, runner_execution_context, bundle_context_manager, bundle_input)
#     768
#     769     last_result, deferred_inputs, newly_set_timers, watermark_updates = (
# --> 770         self._run_bundle(
#     771             runner_execution_context,
#     772             bundle_context_manager,
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, bundle_input, data_output, expected_timer_output, bundle_manager)
#     997         expected_timer_output)
#     998
# --> 999     result, splits = bundle_manager.process_bundle(
#    1000         data_input, data_output, input_timers, expected_timer_output)
#    1001     # Now we collect all the deferred inputs remaining from bundle execution.
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1307             process_bundle_descriptor.id,
#    1308             cache_tokens=[next(self._cache_token_generator)]))
# -> 1309     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1310
#    1311     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py in push(self, request)
#     378       self._uid_counter += 1
#     379       request.instruction_id = 'control_%s' % self._uid_counter
# --> 380     response = self.worker.do_instruction(request)
#     381     return ControlFuture(request.instruction_id, response)
#     382
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in do_instruction(self, request)
#     595     if request_type:
#     596       # E.g. if register is set, this will call self.register(request.register))
# --> 597       return getattr(self, request_type)(
#     598           getattr(request, request_type), request.instruction_id)
#     599     else:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in process_bundle(self, request, instruction_id)
#     633         with self.maybe_profile(instruction_id):
#     634           delayed_applications, requests_finalization = (
# --> 635               bundle_processor.process_bundle(instruction_id))
#     636           monitoring_infos = bundle_processor.monitoring_infos()
#     637           monitoring_infos.extend(self.state_cache_metrics_fn())
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_bundle(self, instruction_id)
#    1001                   element.timer_family_id, timer_data)
#    1002           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
# -> 1003             input_op_by_transform_id[element.transform_id].process_encoded(
#    1004                 element.data)
#    1005
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     225       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     226           input_stream, True)
# --> 227       self.output(decoded_value)
#     228
#     229   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\worker\operations.cp38-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\apache_beam\runners\common.cp38-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      88
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#      92
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      97       with metadata.Metadata(self._mlmd_connection_config) as mlmd_handle:
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#     101         mlmd_connection=metadata.Metadata(self._mlmd_connection_config),
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     569               executor_watcher.address)
#     570           executor_watcher.start()
# --> 571         executor_output = self._run_executor(execution_info)
#     572       except Exception as e:  # pylint: disable=broad-except
#     573         execution_output = (
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     444     outputs_utils.make_output_dirs(execution_info.output_dict)
#     445     try:
# --> 446       executor_output = self._executor_operator.run_executor(execution_info)
#     447       code = executor_output.execution_result.code
#     448       if code != 0:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     133         pipeline_run_id=execution_info.pipeline_run_id)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      56
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#      60   if not result:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\components\tuner\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     120       raise ValueError("TuneArgs is not supported by this Tuner's Executor.")
#     121
# --> 122     tuner = search(input_dict, exec_properties, self._get_tmp_dir())
#     123
#     124     write_best_hyperparameters(tuner, output_dict)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tfx\components\tuner\executor.py in search(input_dict, exec_properties, working_dir)
#     104   result.search_space_summary()
#     105   logging.info('Start tuning... Tuner ID: %s', result.tuner_id)
# --> 106   result.search(**tuner_fn_result.fit_kwargs)
#     107   logging.info('Finished tuning... Tuner ID: %s', result.tuner_id)
#     108   result.results_summary()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     181
#     182             self.on_trial_begin(trial)
# --> 183             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     184             # `results` is None indicates user updated oracle in `run_trial()`.
#     185             if results is None:
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\tuners\hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     382             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     383             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 384         return super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#     385
#     386     def _build_model(self, hp):
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\tuner.py in run_trial(self, trial, *args, **kwargs)
#     293             callbacks.append(model_checkpoint)
#     294             copied_kwargs["callbacks"] = callbacks
# --> 295             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     296
#     297             histories.append(obj_value)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     220         hp = trial.hyperparameters
#     221         model = self._try_build(hp)
# --> 222         results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     223         tuner_utils.validate_trial_results(
#     224             results, self.oracle.objective, "HyperModel.fit()"
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras_tuner\engine\hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     138             If return a float, it should be the `objective` value.
#     139         """
# --> 140         return model.fit(*args, **kwargs)
#     141
#     142
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2451       (graph_function,
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453     return graph_function._call_flat(
#    2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1858         and executing_eagerly):
#    1859       # No tape is watching; skip to running the function.
# -> 1860       return self._build_call_outputs(self._inference_function.call(
#    1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     495       with _InterpolateFunctionError(self):
#     496         if cancellation_manager is None:
# --> 497           outputs = execute.execute(
#     498               str(self.signature.name),
#     499               num_outputs=self._num_outputs,
#
# c:\Users\Zis\anaconda3\envs\stroke-pred\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# RuntimeError: KeyboardInterrupt [while running 'Run[Tuner]']
